# %% [markdown]
# # wordnet Lemmatizer

# %% [markdown]
# This is like stemming
# O/P we get after lemmatization is called lemma which is root word rather than root stem, the output of stemming
# After lemmatization we will be getting a valid word that means the same thing
#
# NLTK provides WordNetLemmatizer class which is a thin wrapper around wordnet corpus.
# This class uses morphy() function to the WordNet CorpusReader class to find lemma.
#
#
# Q&A chat bots, text summarization

# %%
pip install nltk
# Out:
# ...
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ----------------- ---------------------- 0.8/1.8 MB 3.3 MB/s eta 0:00:01
#    ----------------------------- ---------- 1.3/1.8 MB 3.0 MB/s eta 0:00:01
#    ---------------------------------------- 1.8/1.8 MB 3.4 MB/s  0:00:00
# ...
#
#    ---------------------------------------- 0/4 [tqdm]
#    ---------- ----------------------------- 1/4 [regex]
#    -------------------- ------------------- 2/4 [defusedxml]
#    ------------------------------ --------- 3/4 [nltk]
#    ------------------------------ --------- 3/4 [nltk]
#    ------------------------------ --------- 3/4 [nltk]
#    ------------------------------ --------- 3/4 [nltk]
#    ------------------------------ --------- 3/4 [nltk]
#    ------------------------------ --------- 3/4 [nltk]
#    ------------------------------ --------- 3/4 [nltk]
#    ------------------------------ --------- 3/4 [nltk]
#    ------------------------------ --------- 3/4 [nltk]
# ...

# %%
from nltk.stem import WordNetLemmatizer
import nltk
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\VamseedharVantimitta\AppData\Roaming\nltk_dat
# [nltk_data]     a...
# [nltk_data]   Unzipping tokenizers\punkt_tab.zip.
# True

# %%
words=["eating", "eats", "eaten", "Writing", "Writes", "Programming", "Programs", "History", "finally", "Finalize"]

# %%
import nltk
nltk.download('wordnet')
lemmatizer=WordNetLemmatizer()

## pos - noun n, verb v adjective a adverb r
for word in words:
    print(word+"======================="+lemmatizer.lemmatize(word, pos='v'))
# Out:
# eating=======================eat
# eats=======================eat
# eaten=======================eat
# Writing=======================Writing
# Writes=======================Writes
# Programming=======================Programming
# Programs=======================Programs
# History=======================History
# finally=======================finally
# Finalize=======================Finalize
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\vamse\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# # Stop words
#
# not, I the he she there are kind of stop words which are not important will be removed from content

# %%
from nltk.stem import PorterStemmer
from nltk.corpus import stopwords
import nltk
nltk.download('stopwords')
stopwords.words('english')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\VamseedharVantimitta\AppData\Roaming\nltk_dat
# [nltk_data]     a...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# ['a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  "he'd",
#  "he'll",
#  'her',
#  'here',
#  'hers',
#  'herself',
#  "he's",
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  "i'd",
# ...

# %%
paragraph="The Employees' Pension Scheme, 1995, notified under Section 6A of the EPF & MP Act, 1952, provides pensionary benefits to eligible employees of establishments covered under the Act. It ensures monthly pension on superannuation, early retirement, permanent disability, and offers family pension in case of member’s demise. Employers contribute 8.33% of wages and the Central Government contributes 1.16% (subject to wage ceiling) towards the Pension Fund. Members with minimum 10 years of eligible service are entitled to pension; others may opt for withdrawal benefits or scheme certificate."

# %%
from nltk.stem import PorterStemmer
stemmer=PorterStemmer()
sentences=nltk.sent_tokenize(paragraph)

# %%
from nltk.stem import SnowballStemmer
from nltk.stem import WordNetLemmatizer
## apply stopwords and filter and them apply stemming
snowballStemmer=SnowballStemmer('english')
wordNetLemmatizer=WordNetLemmatizer()
for i in range(len(sentences)):
    words=nltk.word_tokenize(sentences[i])
    #snow ball stemmer
    #words=[snowballStemmer.stem(word) for word in words if word not in set(stopwords.words('english'))]
    #lemmatizer
    words=[wordNetLemmatizer.lemmatize(word) for word in words if word not in set(stopwords.words('english'))]
    sentences[i]=' '.join(words)#converting all the list of words into sentences

print(sentences)
# Out:
# ["The Employees ' Pension Scheme , 1995 , notified Section 6A EPF & MP Act , 1952 , provides pensionary benefit eligible employee establishment covered Act .", 'It ensures monthly pension superannuation , early retirement , permanent disability , offer family pension case member ’ demise .', 'Employers contribute 8.33 % wage Central Government contributes 1.16 % ( subject wage ceiling ) towards Pension Fund .', 'Members minimum 10 year eligible service entitled pension ; others may opt withdrawal benefit scheme certificate .']

# %% [markdown]
# # Parts of speach tagging
# if we are giving it as verb or noun then we get root word

# %%
import nltk

sentences=nltk.sent_tokenize(paragraph)
# we will find pos tag parts of speach pos

for i in range(len(sentences)):
    words=nltk.word_tokenize(sentences[i])
    words=[word for word in words if word not in set(stopwords.words('english'))]
    #pos_tag=nltk.pos_tag(words)
    print(words)
# Out:
# ['The', 'Employees', "'", 'Pension', 'Scheme', ',', '1995', ',', 'notified', 'Section', '6A', 'EPF', '&', 'MP', 'Act', ',', '1952', ',', 'provides', 'pensionary', 'benefits', 'eligible', 'employees', 'establishments', 'covered', 'Act', '.']
# ['It', 'ensures', 'monthly', 'pension', 'superannuation', ',', 'early', 'retirement', ',', 'permanent', 'disability', ',', 'offers', 'family', 'pension', 'case', 'member', '’', 'demise', '.']
# ['Employers', 'contribute', '8.33', '%', 'wages', 'Central', 'Government', 'contributes', '1.16', '%', '(', 'subject', 'wage', 'ceiling', ')', 'towards', 'Pension', 'Fund', '.']
# ['Members', 'minimum', '10', 'years', 'eligible', 'service', 'entitled', 'pension', ';', 'others', 'may', 'opt', 'withdrawal', 'benefits', 'scheme', 'certificate', '.']

# %%
import nltk

# 1. Download the required text tokenizers and the correct English POS tagger
nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('averaged_perceptron_tagger_eng')

# 2. Put the extra arguments INSIDE the pos_tag function parenthesis
words = "Taj mahal is not beautiful".split()
tagged_words = nltk.pos_tag(words, tagset=None, lang="eng")

print(tagged_words)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\VamseedharVantimitta\AppData\Roaming\nltk_dat
# [nltk_data]     a...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\VamseedharVantimitta\AppData\Roaming\nltk_dat
# [nltk_data]     a...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     C:\Users\VamseedharVantimitta\AppData\Roaming\nltk_dat
# [nltk_data]     a...
# [('Taj', 'NNP'), ('mahal', 'NN'), ('is', 'VBZ'), ('not', 'RB'), ('beautiful', 'JJ')]
# [nltk_data]   Unzipping taggers\averaged_perceptron_tagger_eng.zip.
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# ...
