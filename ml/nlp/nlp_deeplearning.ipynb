# %% [markdown]
# ## NLP in deep learning
#
#  Text data --> vector --> Numarical representation
#
#  One hot encoding
#  BOW
#  TF-IDF
#  word2vec, avg word2vec(sentiment analysis, text classification)
#
#  ANN --> Artificial neural network(classification, regression) - sequence of data does not matter
#
#  CNN - convolutional neural network - image classification object detection
#
#  Data --> Sequential data
#
#  1. Text generation --> this is a apple
#  2. chhat bot conversation --> Q&A --> sequence of question is important for conversational context
#  3. Language translation -->
#  4. Auto suggestion
#  5. Sales data - If sale data is based on date time
#
#  Can we use ANN to solve this problem - sequential data
#
#  NLP in deep learning (generative ai --> LLM multi model)
#
#  1. Simple RNN --> LSTM/GRU RNN --> Bi-directional RNN --> Encoders and decoders --> Self attention --> Transformers --> Generative AI

# %%
from gensim.models import KeyedVectors
w_reloaded = KeyedVectors.load("word2vec_google_news.kv")
