# %%
pip install NLTK
# Out:
# ...
#   Using cached click-8.5.0-py3-none-any.whl.metadata (2.6 kB)
# ...
#   Using cached regex-2026.9.3-cp313-cp313-win_amd64.whl.metadata (41 kB)
# ...
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 1.8/1.8 MB 13.0 MB/s  0:00:00
# Using cached regex-2026.9.3-cp313-cp313-win_amd64.whl (277 kB)
# Using cached click-8.5.0-py3-none-any.whl (125 kB)
# ...
#
#    ----- ---------------------------------- 1/7 [regex]
#    ---------------------- ----------------- 4/7 [click]
#    ---------------------------- ----------- 5/7 [joblib]
#    ---------------------------- ----------- 5/7 [joblib]
#    ---------------------------------- ----- 6/7 [NLTK]
#    ---------------------------------- ----- 6/7 [NLTK]
#    ---------------------------------- ----- 6/7 [NLTK]
#    ---------------------------------- ----- 6/7 [NLTK]
#    ---------------------------------- ----- 6/7 [NLTK]
#    ---------------------------------- ----- 6/7 [NLTK]
# ...

# %%
corpus="Hello welcome to NLP practice. This will be my first NLP session. It's really great to learn NLP!"

# %%
print(corpus)
# Out:
# Hello welcome to NLP practice. This will be my first NLP session. It's really great to learn NLP!

# %%
#Tokenization
## sentence --> paragraphs
from nltk.tokenize import sent_tokenize
from nltk.tokenize import word_tokenize
import nltk
nltk.download('punkt_tab')
documents = sent_tokenize(corpus, language="english")
for sentence in documents:
    words = word_tokenize(sentence)
    for word in words:
        print(word)
# Out:
# Hello
# welcome
# to
# NLP
# practice
# .
# This
# will
# be
# my
# first
# NLP
# session
# .
# It
# 's
# really
# great
# to
# learn
# NLP
# !
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\vamse\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!

# %%
# Tokenization
## Paragraph --> Words
## SEntence --> Words
from nltk.tokenize import word_tokenize

words = word_tokenize(corpus)
for word in words:
    print(word)
# Out:
# Hello
# welcome
# to
# NLP
# practice
# .
# This
# will
# be
# my
# first
# NLP
# session
# .
# It
# 's
# really
# great
# to
# learn
# NLP
# !

# %%
from nltk.tokenize import TreebankWordDetokenizer
tokenizer = TreebankWordDetokenizer()
treeBank = tokenizer.tokenize(corpus)
print(treeBank)
# Out:
# H e l l o   w e l c o m e   t o   N L P   p r a c t i c e.   T h i s   w i l l   b e   m y   f i r s t   N L P   s e s s i o n.   I t' s   r e a l l y   g r e a t   t o   l e a r n   N L P!

# %% [markdown]
# # Stemming
#
# ## Stemming is the process of reducing a word to its word stem that affixes to suffixes and prefixes or to the roots of words known as a lemma. Stemming is important in natural language understanding NLU and Natural Language Processing NLP

# %%
## classification problem
## Comments of the product is a positive review or negative review

# %% [markdown]
# # PorterStemmer

# %%
words=["eating", "eats", "eaten", "Writing", "Writes", "Programming", "Programs", "History", "finally", "Finalize"]

# %%
from nltk.stem import PorterStemmer


stemmer=PorterStemmer()
for word in words:
    print(word+"========="+stemmer.stem(word))
# Out:
# eating=========eat
# eats=========eat
# eaten=========eaten
# Writing=========write
# Writes=========write
# Programming=========program
# Programs=========program
# History=========histori
# finally=========final
# Finalize=========final

# %% [markdown]
# # RegexpStemmer class
#
# NLTK has RegexpStemmer class with the help of whichwe can easily implement regular expression stemmer algorithms. Its basically takes a single regular expression and removes any prefix and suffix that matches the expression.

# %%
from nltk.stem import RegexpStemmer

reg_stemmer = RegexpStemmer('ing$|s$|e$|able$')
for word in words:
    print(word+"========="+reg_stemmer.stem(word))
# Out:
# eating=========eat
# eats=========eat
# eaten=========eaten
# Writing=========Writ
# Writes=========Write
# Programming=========Programm
# Programs=========Program
# History=========History
# finally=========finally
# Finalize=========Finaliz

# %% [markdown]
# # SnowballStemmer

# %%
from nltk.stem import SnowballStemmer

sbStemmer = SnowballStemmer('english')

for word in words:
    print(word+"========="+sbStemmer.stem(word))
# Out:
# eating=========eat
# eats=========eat
# eaten=========eaten
# Writing=========write
# Writes=========write
# Programming=========program
# Programs=========program
# History=========histori
# finally=========final
# Finalize=========final

# %%
sbStemmer.stem("History")

# History gives histori - this kind of problems are resolved in lemmitization
# Out:
# 'histori'
